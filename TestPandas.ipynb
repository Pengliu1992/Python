# %%
import pandas as pd
import numpy as np

# %%
#read data from File

df=pd.read_csv('pokemon_data.csv')
df1=pd.read_excel('pokemon_data.xlsx')
df2=pd.read_csv('pokemon_data.txt',delimiter='\t')
df1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#Select columns

df[['Name', 'Type 1','Type 2']]
# Out:
#                       Name   Type 1  Type 2
# 0                Bulbasaur    Grass  Poison
# 1                  Ivysaur    Grass  Poison
# 2                 Venusaur    Grass  Poison
# 3    VenusaurMega Venusaur    Grass  Poison
# 4               Charmander     Fire     NaN
# ..                     ...      ...     ...
# 795                Diancie     Rock   Fairy
# 796    DiancieMega Diancie     Rock   Fairy
# 797    HoopaHoopa Confined  Psychic   Ghost
# 798     HoopaHoopa Unbound  Psychic    Dark
# 799              Volcanion     Fire   Water
#
# [800 rows x 3 columns]

# %%
df.head(1)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary
# 0           1      False

# %%
df.iloc[0]
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
#select by conditions

df.loc[df['Type 1']=='Fire']
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
#select by index

df.iloc[1:5,3:5]
# Out:
#    Type 2  HP
# 1  Poison  60
# 2  Poison  80
# 3  Poison  80
# 4     NaN  39

# %%
#Sort

df.sort_values(['Type 1','Type 2'],ascending=[1,0])
# Out:
#        #                 Name Type 1 Type 2   HP  Attack  Defense  Sp. Atk  \
# 307  283              Surskit    Bug  Water   40      30       32       50
# 220  205           Forretress    Bug  Steel   75      90      140       60
# 228  212               Scizor    Bug  Steel   70     130      100       55
# 229  212    ScizorMega Scizor    Bug  Steel   70     150      140       65
# 460  413  WormadamTrash Cloak    Bug  Steel   60      69       95       69
# ..   ...                  ...    ...    ...  ...     ...      ...      ...
# 655  594            Alomomola  Water    NaN  165      75       80       40
# 724  656              Froakie  Water    NaN   41      56       40       62
# 725  657            Frogadier  Water    NaN   54      63       52       83
# 762  692            Clauncher  Water    NaN   50      53       62       58
# 763  693            Clawitzer  Water    NaN   71      73       88      120
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.drop(columns=['Generation'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary
# 0         65       65     45      False
# 1         80       80     60      False
# ...

# %%
#Add columns summation

df['Total']=df.iloc[:,4:10].sum(axis=1)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
L1=list(df.columns)
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'HP']

# %%
new_df=df.loc[(df['Type 1']=='Fire') & (df['Type 2']=='Flying') & (df['HP']>=90)]

# %%
new_df.to_csv('Modified.csv',index=False)

# %%
new_df.reset_index(drop=True,inplace=True)
new_df
# Out:
#      #     Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  146  Moltres   Fire  Flying   90     100       90      125       85     90
# 1  250    Ho-oh   Fire  Flying  106     130       90      110      154     90
#
#    Generation  Legendary  Total
# 0           1       True    580
# 1           2       True    680

# %%
import re
df.loc[df['Name'].str.contains('Mega',regex=True)]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
import re
df.loc[df['Type 1'].str.contains('fire|Water',flags=re.I,regex=True)]
# Out:
#        #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 4      4                 Charmander   Fire     NaN  39      52       43
# 5      5                 Charmeleon   Fire     NaN  58      64       58
# 6      6                  Charizard   Fire  Flying  78      84       78
# 7      6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8      6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# ..   ...                        ...    ...     ...  ..     ...      ...
# 735  667                     Litleo   Fire  Normal  62      50       58
# 736  668                     Pyroar   Fire  Normal  86      68       72
# 762  692                  Clauncher  Water     NaN  50      53       62
# 763  693                  Clawitzer  Water     NaN  71      73       88
# 799  721                  Volcanion   Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
df.loc[df['Name'].str.contains('p[i,e][c,k]',flags=re.I,regex=True)]
# Out:
#        #     Name    Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 30    25  Pikachu  Electric    NaN  35      55       40       50       50
# 186  172    Pichu  Electric    NaN  20      40       15       35       35
#
#      Speed  Generation  Legendary  Total
# 30      90           1      False    320
# 186     60           2      False    205

# %%
df=pd.read_csv('pokemon_data.csv')

df.loc[df['HP']>100,['HP','Type 2']]=[300,'Tank']

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.groupby(['Type 1']).mean().sort_values('HP',ascending=False)

df['count']=1

df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
#         Tank         9
# Name: count, Length: 146, dtype: int64

# %%
for dfs in pd.read_csv('Modified.csv',chunksize=2):
    print('CHK DF:')
    print(dfs)
# Out:
# CHK DF:
#      #     Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  146  Moltres   Fire  Flying   90     100       90      125       85     90
# 1  250    Ho-oh   Fire  Flying  106     130       90      110      154     90
#
#    Generation  Legendary  Total
# 0           1       True    580
# 1           2       True    680

# %%
import matplotlib.pyplot as plt

df=pd.read_csv('pokemon_data.csv')

L1=df['Attack']
L2=df['HP']

m1=['black' if y<50 and z<50 else 'blue' if x>0 else 'red' for x,y,z in zip((L1[L1>L2]-L2[L1>L2]),L1[L1>L2],L2[L1>L2])]

m2=['black' if y<50 and z<50 else 'blue' if x>0 else 'red' for x,y,z in zip((L1[L1<=L2]-L2[L1<=L2]),L1[L1<=L2],L2[L1<=L2])]


plt.scatter(L1[L1>L2],L2[L1>L2],c=m1,s=abs(L1[L1>L2]-L2[L1>L2]),marker='^',label='Attack Type')

plt.scatter(L1[L1<=L2],L2[L1<=L2],c=m2,s=abs(L1[L1<=L2]-L2[L1<=L2]),marker='o',label='Tank Type')

plt.legend()

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
Clist=['Attack','Speed','HP']

df['SubTotal']=df[Clist].sum(axis=1)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  SubTotal
# 0         65       65     45           1      False       139
# ...

# %%
def func(m):
    return m**2

df[Clist].apply(func)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  SubTotal  TryApply      1
# ...

# %%
Clist
# Out:
# ['Attack', 'Speed', 'HP']
